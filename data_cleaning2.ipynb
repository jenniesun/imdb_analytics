# %%
import pandas as pd
import numpy as np

# %%
basics = pd.read_csv("./title.basics_cleaned.csv", sep=",", low_memory=False)

# %%
basics.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1     tconst titleType  \
# 0           0             0               0  tt0000001     short
# 1           1             1               1  tt0000002     short
# 2           2             2               2  tt0000003     short
# 3           3             3               3  tt0000004     short
# 4           4             4               4  tt0000005     short
#
#              primaryTitle           originalTitle  isAdult  startYear  \
# 0              Carmencita              Carmencita        0     1894.0
# 1  Le clown et ses chiens  Le clown et ses chiens        0     1892.0
# 2          Pauvre Pierrot          Pauvre Pierrot        0     1892.0
# 3             Un bon bock             Un bon bock        0     1892.0
# 4        Blacksmith Scene        Blacksmith Scene        0     1893.0
#
#    endYear runtimeMinutes                    genres
# 0        0              1         Documentary Short
# 1        0              5           Animation Short
# 2        0              4  Animation Comedy Romance
# 3        0             12           Animation Short
# 4        0              1              Comedy Short

# %%
basics[basics["runtimeMinutes"]=="Documentary"]
# Out:
#          Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1      tconst  titleType  \
# 1922284     1922284       1922284         1922284  tt11670006  tvEpisode
#
#                                               primaryTitle originalTitle  \
# 1922284  ...ein angenehmer Unbequemer...\t...ein angene...             0
#
#          isAdult  startYear  endYear runtimeMinutes genres
# 1922284     1981        NaN        0    Documentary    NaN

# %%
basics[basics["runtimeMinutes"].str.isnumeric() == False]
# Out:
#          Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1      tconst  titleType  \
# 1922284     1922284       1922284         1922284  tt11670006  tvEpisode
# 2036179     2036179       2036179         2036179  tt11868642  tvEpisode
# 2196838     2196838       2196838         2196838  tt12149332  tvEpisode
#
#                                               primaryTitle originalTitle  \
# 1922284  ...ein angenehmer Unbequemer...\t...ein angene...             0
# 2036179  GGN Heavyweight Championship Lungs With Mike T...             0
# 2196838  Jeopardy! College Championship Semifinal Game ...             0
#
#          isAdult  startYear  endYear runtimeMinutes genres
# 1922284     1981        NaN        0    Documentary    NaN
# 2036179     2020        NaN        0      Talk-Show    NaN
# 2196838     2020        NaN        0      Game-Show    NaN

# %%
basics['runtimeMinutes'] = basics['runtimeMinutes'].replace(r'Documentary', np.nan)

# %%
basics['runtimeMinutes'] = basics['runtimeMinutes'].replace(r'Talk-Show', np.nan)

# %%
basics['runtimeMinutes'] = basics['runtimeMinutes'].replace(r'Game-Show', np.nan)

# %%
basics['runtimeMinutes'].dtype
# Out:
# dtype('O')

# %%
basics[basics['runtimeMinutes'].isnull() == True]
# Out:
#          Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1      tconst  titleType  \
# 1101863     1101863       1101863         1101863  tt10233364  tvEpisode
# 1922284     1922284       1922284         1922284  tt11670006  tvEpisode
# 2036179     2036179       2036179         2036179  tt11868642  tvEpisode
# 2196838     2196838       2196838         2196838  tt12149332  tvEpisode
# 2348021     2348021       2348021         2348021  tt12415330  tvEpisode
# 4516540     4516540       4516540         4516540   tt3984412  tvEpisode
#
#                                               primaryTitle originalTitle  \
# 1101863  Rolling in the Deep Dish\tRolling in the Deep ...             0
# 1922284  ...ein angenehmer Unbequemer...\t...ein angene...             0
# 2036179  GGN Heavyweight Championship Lungs With Mike T...             0
# 2196838  Jeopardy! College Championship Semifinal Game ...             0
# 2348021  Anthony Davis High Brow Tank\tAnthony Davis Hi...             0
# 4516540  I'm Not Going to Come Last, I'm Just Going to ...             0
#
#          isAdult  startYear  endYear runtimeMinutes genres
# 1101863     2019        NaN        0            NaN    NaN
# 1922284     1981        NaN        0            NaN    NaN
# 2036179     2020        NaN        0            NaN    NaN
# 2196838     2020        NaN        0            NaN    NaN
# 2348021     2017        NaN        0            NaN    NaN
# 4516540     2014        NaN        0            NaN    NaN

# %%
basics.to_csv("title.basics_cleaned_v4.csv")
